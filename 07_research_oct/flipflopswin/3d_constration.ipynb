# %% [markdown]
# <br>
# <br>
#
# # `#3D Constractions:`
#
# <br>
# <br>

# %%
#%pip install antspyx SimpleITK

# %%
import os 
import SimpleITK as sit

# %%
image_viwer = sit.ImageViewer()
print(f"default image viwer: {image_viwer}")
# Out:
# default image viwer: itk::simple::ImageViewer
#   Title:
#   Command: %a -eval 'open("%f"); rename("%t");'
#   Application:
#   Default Application:
#   File Extension: .mha
#   Default File Extension: .mha
#   Search Path: [ C:\Program Files\, C:\Program Files (x86)\, C:\Program Files\, C:\Users\CSITOCT\, C:\Users\CSITOCT\Desktop\ ]
#   Executable Names: [ Fiji.app/ImageJ-win64.exe, Fiji.app/ImageJ-win32.exe ]
#   Debug Flag: 0
